# %%
# !git clone https://github.com/Ewha-2025-2-Introduction-to-ML-termPJT/demo-repository.git
# Out:
# Cloning into 'demo-repository'...
# remote: Enumerating objects: 136, done.
# remote: Counting objects: 100% (136/136), done.
# remote: Compressing objects: 100% (108/108), done.
# remote: Total 136 (delta 70), reused 65 (delta 26), pack-reused 0 (from 0)
# Receiving objects: 100% (136/136), 39.89 KiB | 5.70 MiB/s, done.
# Resolving deltas: 100% (70/70), done.

# %%
# %cd /content/demo-repository
# !git status
# Out:
# /content/demo-repository
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git status
# !git branch -a
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# * main
#   remotes/origin/HEAD -> origin/main
#   remotes/origin/add-badges-to-readme
#   remotes/origin/dev
#   remotes/origin/main

# %%
# !git checkout dev
# Out:
# Branch 'dev' set up to track remote branch 'dev' from 'origin'.
# Switched to a new branch 'dev'

# %%
# !git branch
# Out:
# * dev
#   main

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 108.6 MB/s eta 0:00:00
# ...

# %%
# !python -m src.data.process
# Out:
# Preprocessed files not found. Running full preprocessing pipeline...
# Folder created at: ./input_data
#
# ...
# Using Colab cache for faster access to the 'urbansound8k' dataset.
# Download complete! Path: /kaggle/input/urbansound8k
# Contents in folder: ['fold7', 'fold1', 'fold3', 'fold5', 'fold10', 'UrbanSound8K.csv', 'fold9', 'fold8', 'fold4', 'fold2', 'fold6']
#
# Start proprocessing...
#  41% 3554/8732 [06:04<08:00, 10.77it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1323
#   warnings.warn(
#  95% 8325/8732 [13:32<00:34, 11.71it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1103
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1523
#   warnings.warn(
# 100% 8732/8732 [14:08<00:00, 10.29it/s]
#
# ...

# %%
# %cd /content/demo-repository
# !python -m src.scripts.train_scratch
# Out:
# /content/demo-repository
# Found preprocessed files. Loading from disk...
# batch X: torch.Size([64, 1, 40, 174])
# batch y: torch.Size([64])
# [Scratch Epoch 1/30] Train Loss: 2.2613 | Train Acc: 0.1264 | Val Loss: 2.1689 | Val Acc: 0.1176
#   → Best Scratch saved!
# [Scratch Epoch 2/30] Train Loss: 2.1760 | Train Acc: 0.1738 | Val Loss: 1.9933 | Val Acc: 0.2770
#   → Best Scratch saved!
# [Scratch Epoch 3/30] Train Loss: 2.0500 | Train Acc: 0.2392 | Val Loss: 1.8223 | Val Acc: 0.2647
#   → Best Scratch saved!
# [Scratch Epoch 4/30] Train Loss: 1.9417 | Train Acc: 0.2817 | Val Loss: 1.7371 | Val Acc: 0.2966
#   → Best Scratch saved!
# [Scratch Epoch 5/30] Train Loss: 1.8817 | Train Acc: 0.3108 | Val Loss: 1.6738 | Val Acc: 0.3431
#   → Best Scratch saved!
# [Scratch Epoch 6/30] Train Loss: 1.8242 | Train Acc: 0.3242 | Val Loss: 1.6458 | Val Acc: 0.3297
#   → Best Scratch saved!
# [Scratch Epoch 7/30] Train Loss: 1.7803 | Train Acc: 0.3469 | Val Loss: 1.5916 | Val Acc: 0.3738
# ...

# %%
# !python3 -m src.scripts.train_finetune
# Out:
# Found preprocessed files. Loading from disk...
# batch X: torch.Size([64, 1, 40, 174])
# batch y: torch.Size([64])
# [FFT Epoch 1/30] Train Loss: 1.4680 | Train Acc: 0.4715 | Val Loss: 1.3845 | Val Acc: 0.4240
#   → Best FFT saved!
# [FFT Epoch 2/30] Train Loss: 1.4670 | Train Acc: 0.4705 | Val Loss: 1.3501 | Val Acc: 0.4534
#   → Best FFT saved!
# [FFT Epoch 3/30] Train Loss: 1.4436 | Train Acc: 0.4783 | Val Loss: 1.3597 | Val Acc: 0.4363
# [FFT Epoch 4/30] Train Loss: 1.4354 | Train Acc: 0.4816 | Val Loss: 1.3900 | Val Acc: 0.4632
# [FFT Epoch 5/30] Train Loss: 1.4248 | Train Acc: 0.4823 | Val Loss: 1.3369 | Val Acc: 0.4485
#   → Best FFT saved!
# [FFT Epoch 6/30] Train Loss: 1.4134 | Train Acc: 0.4889 | Val Loss: 1.3538 | Val Acc: 0.4338
# [FFT Epoch 7/30] Train Loss: 1.4083 | Train Acc: 0.4896 | Val Loss: 1.3426 | Val Acc: 0.4449
# [FFT Epoch 8/30] Train Loss: 1.3970 | Train Acc: 0.4951 | Val Loss: 1.3418 | Val Acc: 0.4547
# ...

# %%
# !python3 -m src.scripts.train_lora
# Out:
# Found preprocessed files. Loading from disk...
# batch X: torch.Size([64, 1, 40, 174])
# batch y: torch.Size([64])
# [LoRA Epoch 1/30] Train Loss: 1.4365 | Train Acc: 0.4802 | Val Loss: 1.3708 | Val Acc: 0.4461
#   → Best LoRA saved!
# [LoRA Epoch 2/30] Train Loss: 1.4269 | Train Acc: 0.4871 | Val Loss: 1.3533 | Val Acc: 0.4449
#   → Best LoRA saved!
# [LoRA Epoch 3/30] Train Loss: 1.4248 | Train Acc: 0.4879 | Val Loss: 1.3662 | Val Acc: 0.4461
# [LoRA Epoch 4/30] Train Loss: 1.4219 | Train Acc: 0.4835 | Val Loss: 1.3552 | Val Acc: 0.4534
# [LoRA Epoch 5/30] Train Loss: 1.4186 | Train Acc: 0.4943 | Val Loss: 1.3505 | Val Acc: 0.4571
#   → Best LoRA saved!
# [LoRA Epoch 6/30] Train Loss: 1.4147 | Train Acc: 0.4917 | Val Loss: 1.3528 | Val Acc: 0.4681
# [LoRA Epoch 7/30] Train Loss: 1.4070 | Train Acc: 0.4948 | Val Loss: 1.3390 | Val Acc: 0.4485
#   → Best LoRA saved!
# [LoRA Epoch 8/30] Train Loss: 1.4050 | Train Acc: 0.4943 | Val Loss: 1.3479 | Val Acc: 0.4498
# ...

# %%
# !python3 -m src.scripts.train_adapter
# Out:
# Found preprocessed files. Loading from disk...
# batch X: torch.Size([64, 1, 40, 174])
# batch y: torch.Size([64])
# [Adapter Epoch 1/30] Train Loss: 1.4510 | Train Acc: 0.4705 | Val Loss: 1.3915 | Val Acc: 0.4387
#   → Best Adapter saved!
# [Adapter Epoch 2/30] Train Loss: 1.4119 | Train Acc: 0.4876 | Val Loss: 1.3940 | Val Acc: 0.4485
# [Adapter Epoch 3/30] Train Loss: 1.3906 | Train Acc: 0.4964 | Val Loss: 1.4084 | Val Acc: 0.4301
# [Adapter Epoch 4/30] Train Loss: 1.3699 | Train Acc: 0.5047 | Val Loss: 1.3307 | Val Acc: 0.4669
#   → Best Adapter saved!
# [Adapter Epoch 5/30] Train Loss: 1.3604 | Train Acc: 0.5122 | Val Loss: 1.3137 | Val Acc: 0.4694
#   → Best Adapter saved!
# [Adapter Epoch 6/30] Train Loss: 1.3471 | Train Acc: 0.5189 | Val Loss: 1.3148 | Val Acc: 0.4988
# [Adapter Epoch 7/30] Train Loss: 1.3325 | Train Acc: 0.5225 | Val Loss: 1.3471 | Val Acc: 0.4792
# [Adapter Epoch 8/30] Train Loss: 1.3221 | Train Acc: 0.5304 | Val Loss: 1.2861 | Val Acc: 0.4865
# ...

# %%
# %cd /content/demo-repository
import sys
sys.path.append("/content/demo-repository")

from src.scripts.compare import main as compare_main
compare_main()
# Out:
# /content/demo-repository
# [DEBUG][test] looking for: /content/demo-repository/results/test_scratch.json
# [DEBUG][test] looking for: /content/demo-repository/results/test_fft.json
# [DEBUG][test] looking for: /content/demo-repository/results/test_lora.json
# [DEBUG][test] looking for: /content/demo-repository/results/test_adapter.json
#                 Model  Trainable Params  Test Accuracy  Test Loss
# 0  Baseline (Scratch)            110474         0.5639     1.2805
# 1    Full Fine-Tuning            110474         0.5950     1.1923
# 2            LoRA CNN             26570         0.6010     1.1983
# 3         Adapter CNN             38890         0.6272     1.1850
#
# | Model              |   Trainable Params |   Test Accuracy |   Test Loss |
# |:-------------------|-------------------:|----------------:|------------:|
# | Baseline (Scratch) |             110474 |          0.5639 |      1.2805 |
# | Full Fine-Tuning   |             110474 |          0.595  |      1.1923 |
# ...
